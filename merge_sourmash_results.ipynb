# %% [markdown]
# ## This notebook merges results from the sourmash-gather output into one sheet with results from all samples. It also summarizes the fraction of base pairs unassigned and assigned to the genus Pelagibacter by sourmash.

# %% [markdown]
# #### Import all required modules

# %%
import pandas as pd
import os as os
import glob as glob
import numpy as np

# %% [markdown]
# #### Navigate to your working directory, which should contain both spreadsheets you want to merge

# %%
os.chdir("/Users/nastassia.patin/Desktop/Projects/Lasker2019/Long read paper/mSystems/Revisions/new-sourmash/nts-GTDB-MMETSP/tax_out")

# %% [markdown]
# #### Import an example sheet

# %%
summary = pd.read_csv("1903c117_50m-1_tax.summarized.csv")
summary.head()
# Out:
#    query_name          rank  fraction                        lineage  \
# 0         NaN  superkingdom  0.057079                    d__Bacteria
# 1         NaN  superkingdom  0.014560                      Eukaryota
# 2         NaN  superkingdom  0.014186                     d__Archaea
# 3         NaN  superkingdom  0.914176                   unclassified
# 4         NaN        phylum  0.037757  d__Bacteria;p__Proteobacteria
#
#   query_md5                          query_filename  f_weighted_at_rank  \
# 0  41f6a87e  1903c117_50m-1_bmtag_interleaved.fq.gz            0.057079
# 1  41f6a87e  1903c117_50m-1_bmtag_interleaved.fq.gz            0.014560
# 2  41f6a87e  1903c117_50m-1_bmtag_interleaved.fq.gz            0.014186
# 3  41f6a87e  1903c117_50m-1_bmtag_interleaved.fq.gz            0.914176
# 4  41f6a87e  1903c117_50m-1_bmtag_interleaved.fq.gz            0.037757
#
#    bp_match_at_rank
# 0          35107000
# 1           8955000
# 2           8725000
# 3           1999000
# 4          23223000

# %%
species = summary[summary['rank'] == 'species']
species = species[['fraction', 'lineage']]

# %%
species
# Out:
#      fraction                                            lineage
# 239  0.006619  Eukaryota;Viridiplantae:Chlorophyta;Prasinophy...
# 240  0.003585  d__Bacteria;p__Proteobacteria;c__Alphaproteoba...
# 241  0.002694  d__Archaea;p__Thermoplasmatota;c__Poseidoniia;...
# 242  0.002675  d__Bacteria;p__Proteobacteria;c__Alphaproteoba...
# 243  0.002379  d__Archaea;p__Thermoplasmatota;c__Poseidoniia;...
# ..        ...                                                ...
# 406  0.000081  d__Bacteria;p__Proteobacteria;c__Alphaproteoba...
# 407  0.000081  d__Bacteria;p__Marinisomatota;c__Marinisomatia...
# 408  0.000081  d__Bacteria;p__Proteobacteria;c__Gammaproteoba...
# 409  0.000081  Eukaryota;Alveolata:Dinophyta;Dinophyceae;Sues...
# 410  0.914176                                       unclassified
#
# [172 rows x 2 columns]

# %% [markdown]
# ## 1. Summarize and combine all sourmash tax summaries

# %% [markdown]
# ### Function to reformat individual data sheet

# %%
def format_sourmash_summary(sheet, sample):
    taxon = sheet[sheet['rank'] == 'species'] # select desired level of taxonomic resolution
    taxon = taxon[['bp_match_at_rank', 'lineage']]
    taxon2 = taxon.groupby(['lineage']).sum()
    taxon2['sample'] = sample
    return(taxon2)

# %% [markdown]
# ### Apply function to all data sheets and combine

# %%
summary = []

for file in glob.glob("*summarized.csv"):
    sheet = pd.read_csv(file)
    a, b, c = file.split('_')
    sample = a + "_" + b
    df = format_sourmash_summary(sheet, sample)
    summary.append(df)

summary = pd.concat(summary)

# %%
summary.head()
# Out:
#                                                     bp_match_at_rank  \
# lineage
# Eukaryota;Cryptophyta:Cryptophyta;Cryptophyceae...             54000
# Eukaryota;Haptophyta:Haptophyta;Prymnesiophycea...            119000
# Eukaryota;Haptophyta:Haptophyta;Prymnesiophycea...            378000
# Eukaryota;Haptophyta:Haptophyta;Prymnesiophycea...             59000
# Eukaryota;Haptophyta:Haptophyta;Prymnesiophycea...            210000
#
#                                                             sample
# lineage
# Eukaryota;Cryptophyta:Cryptophyta;Cryptophyceae...  1903c117_50m-2
# Eukaryota;Haptophyta:Haptophyta;Prymnesiophycea...  1903c117_50m-2
# Eukaryota;Haptophyta:Haptophyta;Prymnesiophycea...  1903c117_50m-2
# Eukaryota;Haptophyta:Haptophyta;Prymnesiophycea...  1903c117_50m-2
# Eukaryota;Haptophyta:Haptophyta;Prymnesiophycea...  1903c117_50m-2

# %% [markdown]
# #### Pivot table so each sample is a column

# %%
summary_pivoted = summary.pivot_table(index='lineage', columns='sample', values='bp_match_at_rank')
summary_pivoted = summary_pivoted.fillna(0)
summary_pivoted.head()
# Out:
# sample                                              1903c111_10m-1  \
# lineage
# Eukaryota;Alveolata:Ciliophora;Litostomatea;Cyc...             0.0
# Eukaryota;Alveolata:Ciliophora;Spirotrichea;Tin...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Suess...             0.0
#
# sample                                              1903c111_10m-2  \
# lineage
# Eukaryota;Alveolata:Ciliophora;Litostomatea;Cyc...             0.0
# Eukaryota;Alveolata:Ciliophora;Spirotrichea;Tin...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Suess...             0.0
#
# sample                                              1903c111_10m-3  \
# lineage
# Eukaryota;Alveolata:Ciliophora;Litostomatea;Cyc...             0.0
# Eukaryota;Alveolata:Ciliophora;Spirotrichea;Tin...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Suess...             0.0
#
# sample                                              1903c117_50m-1  \
# lineage
# Eukaryota;Alveolata:Ciliophora;Litostomatea;Cyc...             0.0
# Eukaryota;Alveolata:Ciliophora;Spirotrichea;Tin...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Suess...             0.0
#
# sample                                              1903c117_50m-2  \
# lineage
# Eukaryota;Alveolata:Ciliophora;Litostomatea;Cyc...             0.0
# Eukaryota;Alveolata:Ciliophora;Spirotrichea;Tin...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Suess...             0.0
#
# sample                                              1903c117_50m-3  \
# lineage
# Eukaryota;Alveolata:Ciliophora;Litostomatea;Cyc...             0.0
# Eukaryota;Alveolata:Ciliophora;Spirotrichea;Tin...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Suess...             0.0
#
# sample                                              1903c118_23m-2  \
# lineage
# Eukaryota;Alveolata:Ciliophora;Litostomatea;Cyc...             0.0
# Eukaryota;Alveolata:Ciliophora;Spirotrichea;Tin...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Suess...             0.0
#
# sample                                              1903c118_23m-3  \
# lineage
# Eukaryota;Alveolata:Ciliophora;Litostomatea;Cyc...             0.0
# Eukaryota;Alveolata:Ciliophora;Spirotrichea;Tin...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Suess...             0.0
#
# sample                                              1903c119_11m-2  \
# lineage
# Eukaryota;Alveolata:Ciliophora;Litostomatea;Cyc...             0.0
# Eukaryota;Alveolata:Ciliophora;Spirotrichea;Tin...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Suess...             0.0
#
# sample                                              1903c119_11m-3  ...  \
# lineage                                                             ...
# Eukaryota;Alveolata:Ciliophora;Litostomatea;Cyc...             0.0  ...
# Eukaryota;Alveolata:Ciliophora;Spirotrichea;Tin...             0.0  ...
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...         94000.0  ...
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...             0.0  ...
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Suess...             0.0  ...
#
# sample                                              1903c144_13m-2  \
# lineage
# Eukaryota;Alveolata:Ciliophora;Litostomatea;Cyc...             0.0
# Eukaryota;Alveolata:Ciliophora;Spirotrichea;Tin...        157000.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Suess...             0.0
#
# sample                                              1903c144_13m-3  \
# lineage
# Eukaryota;Alveolata:Ciliophora;Litostomatea;Cyc...             0.0
# Eukaryota;Alveolata:Ciliophora;Spirotrichea;Tin...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Suess...             0.0
#
# sample                                              Las19c107_10m-1  \
# lineage
# Eukaryota;Alveolata:Ciliophora;Litostomatea;Cyc...              0.0
# Eukaryota;Alveolata:Ciliophora;Spirotrichea;Tin...              0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...              0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...              0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Suess...              0.0
#
# sample                                              Las19c107_10m-2  \
# lineage
# Eukaryota;Alveolata:Ciliophora;Litostomatea;Cyc...              0.0
# Eukaryota;Alveolata:Ciliophora;Spirotrichea;Tin...              0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...              0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...              0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Suess...              0.0
#
# sample                                              Las19c107_10m-3  \
# lineage
# Eukaryota;Alveolata:Ciliophora;Litostomatea;Cyc...              0.0
# Eukaryota;Alveolata:Ciliophora;Spirotrichea;Tin...              0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...              0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...              0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Suess...              0.0
#
# sample                                              Las19c135_5m-1  \
# lineage
# Eukaryota;Alveolata:Ciliophora;Litostomatea;Cyc...             0.0
# Eukaryota;Alveolata:Ciliophora;Spirotrichea;Tin...        206000.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Suess...             0.0
#
# sample                                              Las19c135_5m-2  \
# lineage
# Eukaryota;Alveolata:Ciliophora;Litostomatea;Cyc...             0.0
# Eukaryota;Alveolata:Ciliophora;Spirotrichea;Tin...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...         60000.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Suess...             0.0
#
# sample                                              Las19c135_5m-3  \
# lineage
# Eukaryota;Alveolata:Ciliophora;Litostomatea;Cyc...             0.0
# Eukaryota;Alveolata:Ciliophora;Spirotrichea;Tin...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...             0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Suess...             0.0
#
# sample                                              Las19c138_27m-1  \
# lineage
# Eukaryota;Alveolata:Ciliophora;Litostomatea;Cyc...         100000.0
# Eukaryota;Alveolata:Ciliophora;Spirotrichea;Tin...              0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...          56000.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...         109000.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Suess...              0.0
#
# sample                                              Las19c138_27m-3
# lineage
# Eukaryota;Alveolata:Ciliophora;Litostomatea;Cyc...              0.0
# Eukaryota;Alveolata:Ciliophora;Spirotrichea;Tin...              0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...              0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Gonyu...              0.0
# Eukaryota;Alveolata:Dinophyta;Dinophyceae;Suess...          52000.0
#
# [5 rows x 38 columns]

# %% [markdown]
# #### Save the merged table as a csv

# %%
summary_pivoted.to_csv("Lasker2019_Illumina_PacBio_sourmash_GTDB_MMETSP_species_bpnumbers.csv")

# %% [markdown]
# ## 2. Summarize % unclassified reads and % assigned to genus Pelagibacter

# %%
def extract_fraction_unassigned(sheet, sample):
    taxon = sheet[sheet['rank'] == 'species'] # select desired level of taxonomic resolution
    taxon = taxon[['fraction', 'lineage']]
    unassigned = taxon.loc[taxon['lineage'] == 'unclassified']
    unassigned.insert(len(unassigned.columns), 'sample', sample)
    return(unassigned)

# %%
def extract_fraction_pelagibacter(sheet, sample):
    taxon = sheet[sheet['rank'] == 'genus'] # select desired level of taxonomic resolution
    taxon = taxon[['fraction', 'lineage']]
    SAR11 = taxon.loc[taxon['lineage'].str.contains('Pelagibacter')]
    SAR11.insert(len(SAR11.columns), 'sample', sample)
    return(SAR11)

# %% [markdown]
# #### Summarize % unclassified

# %%
summary = []

for file in glob.glob("*summarized.csv"):
    sheet = pd.read_csv(file)
    a, b, c = file.split('_')
    sample = a + "_" + b
    df = extract_fraction_unassigned(sheet, sample)
    summary.append(df)

frac_unassigned = pd.concat(summary)

# %% [markdown]
# #### Summarize % Pelagibacter

# %%
summary = []

for file in glob.glob("*summarized.csv"):
    sheet = pd.read_csv(file)
    a, b, c = file.split('_')
    sample = a + "_" + b
    df = extract_fraction_pelagibacter(sheet, sample)
    df = df.groupby('sample').sum() # there are couple different Pelagibacter lineages
    df.insert(len(df.columns), 'Genus', 'Pelagibacter') 
    summary.append(df)

frac_pelagibac = pd.concat(summary)

# %%
frac_pelagibac
# Out:
#                  fraction         Genus
# sample
# 1903c117_50m-2   0.000428  Pelagibacter
# 1903c124_15m-3   0.021033  Pelagibacter
# 1903c118_23m-2   0.002269  Pelagibacter
# 1903c129_26m-2   0.000129  Pelagibacter
# 1903c129_26m-1   0.001326  Pelagibacter
# 1903c117_50m-1   0.000834  Pelagibacter
# 1903c127_7m-1    0.001576  Pelagibacter
# Las19c107_10m-2  0.000361  Pelagibacter
# 1903c144_13m-2   0.002834  Pelagibacter
# 1903c126_45m-1   0.000189  Pelagibacter
# 1903c126_45m-2   0.000159  Pelagibacter
# Las19c107_10m-1  0.001591  Pelagibacter
# Las19c138_27m-3  0.001924  Pelagibacter
# Las19c135_5m-3   0.000519  Pelagibacter
# 1903c119_11m-2   0.000535  Pelagibacter
# 1903c127_7m-2    0.001429  Pelagibacter
# 1903c126_45m-3   0.001048  Pelagibacter
# 1903c119_11m-3   0.000073  Pelagibacter
# Las19c135_5m-2   0.001842  Pelagibacter
# 1903c123_10m-2   0.000085  Pelagibacter
# Las19c135_5m-1   0.000992  Pelagibacter
# Las19c138_27m-1  0.000957  Pelagibacter
# 1903c123_10m-1   0.000086  Pelagibacter
# 1903c111_10m-1   0.001503  Pelagibacter
# 1903c122_28m-2   0.000127  Pelagibacter
# 1903c124_15m-1   0.000395  Pelagibacter
# 1903c124_15m-2   0.000349  Pelagibacter
# 1903c117_50m-3   0.005130  Pelagibacter
# 1903c122_28m-1   0.001932  Pelagibacter
# 1903c111_10m-2   0.000542  Pelagibacter

# %%
frac_unassigned.to_csv("Lasker2019_Illumina_PacBio_sourmash_GTDB_MMETSP_fractionunassigned.csv", index=None)

# %%
frac_pelagibac.to_csv("Lasker2019_Illumina_PacBio_sourmash_GTDB_MMETSP_fractionSAR11.csv")
