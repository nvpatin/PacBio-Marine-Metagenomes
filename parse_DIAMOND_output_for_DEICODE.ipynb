# %% [markdown]
# # Take DIAMOND output and make a counts table for each taxonomic assignment to be used for Robust Aitchison Principal Components Analysis (RPCA) in DEICODE

# %% [markdown]
# ### Assembly ORFs were run against NCBI-nr using DIAMOND with the following command: diamond blastp -d /work/hpc/users/nvp29/databases/NCBI-nr/diamond/nr_diamond_tax.dmnd -q $f -o $n'_metaFlye.diamondout' -f 6 qseqid sseqid pident length mismatch gapopen qstart qend sstart send evalue bitscore staxids sscinames stitle --very-sensitive --threads 20

# %%
import pandas as pd
import os as os
import glob as glob
import numpy as np
import sys as sys

# %%
os.chdir("/Users/nastassia.patin/Desktop/Projects/Lasker2019/Long read paper/mSystems/Revisions/new-ORF-annotations/for_deicode-metaflye_illumina_hybrid")

# %% [markdown]
# ### Option 1: One file at a time

# %%
dmnd = pd.read_csv("1903c124_15m_hybridSPAdes.diamondout", sep="\t", header=None, 
                 names=['qseqid', 'sseqid', 'pident', 'length', 'mismatch', 'gapopen', 'qstart', 
                        'qend','sstart', 'send', 'evalue', 'bitscore', 'staxids', 'sscinames',
                        'stitle'])
dmnd = dmnd[['qseqid','bitscore', 'staxids', 'sscinames']]
# filter for hits with a bitscore greater than 50
dmnd_filt = dmnd.loc[dmnd['bitscore'] > 50].copy()
dmnd_filt.loc[: ,'bitscore'] = '1903c124_15m_hybridSPAdes'
dmnd_filt = dmnd_filt.rename(columns={'bitscore' : 'sample'})
dmnd_filt[['count']] = 1
dmnd_filt['staxids'] = dmnd_filt['staxids'].str.split(';', expand=True)[0] # if multiple tax ids, just keep first
dmnd_grped = dmnd_filt.groupby(['staxids', 'sample']).sum()
dmnd_grped = dmnd_grped.reset_index()
dmnd_grped.head()
# Out:
#    staxids                     sample  count
# 0       10  1903c124_15m_hybridSPAdes     20
# 1      100  1903c124_15m_hybridSPAdes     42
# 2   100035  1903c124_15m_hybridSPAdes      2
# 3  1000413  1903c124_15m_hybridSPAdes     21
# 4   100053  1903c124_15m_hybridSPAdes     20

# %%
dmnd_grped.to_csv("1903c124_15m_hybridSPAdes_annotations.csv", index=None)

# %% [markdown]
# ### Concatenate all individual files (bash) and import concatenated annotations files

# %%
annots_all = pd.read_csv("hybridSPAdes_annotations_ALL.csv")
annots_all
# Out:
#          staxids                      sample  count
# 0         999948  Las19c107_10m_hybridSPAdes      3
# 1         999948   1903c123_10m_hybridSPAdes      2
# 2         999948   1903c111_10m_hybridSPAdes      2
# 3         999931  Las19c138_27m_hybridSPAdes      4
# 4         999931  Las19c138_27m_hybridSPAdes      3
# ...          ...                         ...    ...
# 1196972       10   1903c122_28m_hybridSPAdes     12
# 1196973       10   1903c119_11m_hybridSPAdes     15
# 1196974       10   1903c118_23m_hybridSPAdes      5
# 1196975       10   1903c117_50m_hybridSPAdes     29
# 1196976       10   1903c111_10m_hybridSPAdes     34
#
# [1196977 rows x 3 columns]

# %%
annots_all.size
# Out:
# 3590931

# %%
annots_all = annots_all.groupby(['staxids', 'sample']).sum()
df_all = annots_all.reset_index()
df_all
# Out:
#         staxids                      sample  count
# 0             2   1903c111_10m_hybridSPAdes    142
# 1             2   1903c117_50m_hybridSPAdes    187
# 2             2   1903c118_23m_hybridSPAdes     21
# 3             2   1903c119_11m_hybridSPAdes    102
# 4             2   1903c122_28m_hybridSPAdes    240
# ...         ...                         ...    ...
# 682657  2929456   1903c129_26m_hybridSPAdes      5
# 682658  2929456   1903c144_13m_hybridSPAdes      4
# 682659  2929456  Las19c107_10m_hybridSPAdes      3
# 682660  2929456   Las19c135_5m_hybridSPAdes      1
# 682661  2929456  Las19c138_27m_hybridSPAdes     15
#
# [682662 rows x 3 columns]

# %%
df_all.size
# Out:
# 2047986

# %%
df_all.to_csv("hybridSPAdes_annotations_ALL-v2.csv", index=None)

# %%
df_all['staxids'].to_csv("taxids_hybridSPAdes_ALL.txt", index=None, header=False)

# %% [markdown]
# ### Option 2: In a loop if files are small enough (<1.2 GB)

# %%
def format_diamondout_for_qiime(diamondout):
    a, b = diamondout.split('.', maxsplit=2)
    dmnd = pd.read_csv(diamondout, sep="\t", header=None, names=['qseqid', 'sseqid', 'pident', 
                                                                 'length', 'mismatch', 'gapopen', 'qstart', 
                                                                 'qend','sstart', 'send', 'evalue', 'bitscore', 
                                                                 'staxids', 'sscinames', 'stitle']) 
    dmnd = dmnd[['qseqid','bitscore', 'staxids', 'sscinames']]
    
    dmnd_filt = dmnd.loc[dmnd['bitscore'] > 50].copy() 
    dmnd_filt.loc[:, 'bitscore'] = a
    dmnd_filt = dmnd_filt.rename(columns={'bitscore' : 'sample'})
    dmnd_filt[['count']] = 1
    dmnd_filt['staxids'] = dmnd_filt['staxids'].str.split(';', expand=True)[0] # if multiple tax ids, just keep first
    dmnd_grped = dmnd_filt.groupby(['staxids', 'sample']).sum()
    dmnd_grped = dmnd_grped.reset_index()
    return(dmnd_grped)

# %% [markdown]
# #### Run function on all vsearch output files

# %%
df = []

for f in glob.glob("*.diamondout"):
    dmnd_parsed = format_diamondout_for_qiime(f)
    df.append(dmnd_parsed)
    
df_all = pd.concat(df)

# %% [markdown]
# #### If very large files had to be split into sub-files, run the below loop to combine all sub-files into one sample file

# %%
df = []

for f in glob.glob("*.diamondout"):
    a, b = f.split(".", maxsplit=2)
    #print(a)
    sep='-'
    name = [a, "sub.a*"]
    for n in glob.glob(sep.join(name)):
        #print(n)
        dmnd_parsed = format_diamondout_for_qiime(n)
        df.append(dmnd_parsed)
    
df_all = pd.concat(df)

# %%
df_all.head()
# Out:
#    staxids                     sample  count
# 0       10  1903c111_10m-1_SPAdes-sub      7
# 1      100  1903c111_10m-1_SPAdes-sub      8
# 2   100035  1903c111_10m-1_SPAdes-sub      1
# 3  1000413  1903c111_10m-1_SPAdes-sub      7
# 4   100053  1903c111_10m-1_SPAdes-sub      7

# %%
df_all['sample'] = df_all['sample'].str.split('-s', expand=True)[0]
df_all['sample'].unique()

# %%
# Export the dataframe to save and load in the future
df_all.to_csv("Illumina_large_annotations.csv", index=None)

# %% [markdown]
# ### For the 'large' and 'small' data sets, upload and combine and export taxids

# %%
os.chdir("/Users/nastassia.patin/Desktop/Projects/Lasker2019/Long read paper/mSystems/Revisions/new-ORF-annotations/Illumina/")

# %%
df_small = pd.read_csv("Illumina_small_annotations.csv")
df_large = pd.read_csv("Illumina_large_annotations.csv")

# %%
df_illumina = pd.concat([df_small, df_large])
df_illumina
# Out:
#          staxids                 sample  count
# 0             10  1903c126_45m-1_SPAdes      5
# 1            100  1903c126_45m-1_SPAdes     40
# 2         100035  1903c126_45m-1_SPAdes     52
# 3        1000413  1903c126_45m-1_SPAdes    357
# 4         100053  1903c126_45m-1_SPAdes     29
# ...          ...                    ...    ...
# 2729083   999883  1903c129_26m-2_SPAdes      2
# 2729084   999894  1903c129_26m-2_SPAdes      2
# 2729085   999898  1903c129_26m-2_SPAdes      1
# 2729086     9999  1903c129_26m-2_SPAdes     20
# 2729087   999931  1903c129_26m-2_SPAdes      1
#
# [3304967 rows x 3 columns]

# %%
df_illumina = df_illumina.groupby(['staxids', 'sample']).sum()
df_illumina = df_illumina.reset_index()
df_illumina
# Out:
#          staxids                  sample  count
# 0              2   1903c111_10m-1_SPAdes    217
# 1              2   1903c111_10m-2_SPAdes    141
# 2              2   1903c117_50m-1_SPAdes    185
# 3              2   1903c117_50m-2_SPAdes     83
# 4              2   1903c119_11m-2_SPAdes    102
# ...          ...                     ...    ...
# 1141963  2929456  Las19c107_10m-1_SPAdes      3
# 1141964  2929456  Las19c107_10m-2_SPAdes      3
# 1141965  2929456   Las19c135_5m-1_SPAdes      1
# 1141966  2929456   Las19c135_5m-2_SPAdes      1
# 1141967  2929456  Las19c138_27m-1_SPAdes     12
#
# [1141968 rows x 3 columns]

# %%
# Export the taxids to use for the taxonomy metadata file
df_illumina['staxids'].to_csv("taxids_Illumina.txt", index=None, header=False)

# %% [markdown]
# ## Combine the three (Illumina, metaFlye, and hybridSPAdes) data sets into one big DF

# %%
os.chdir("/Users/nastassia.patin/Desktop/Projects/Lasker2019/Long read paper/mSystems/Revisions/new-ORF-annotations/")
df_metaflye = pd.read_csv("metaFlye_annotations_ALL.csv")
df_hybrid = pd.read_csv("hybridSPAdes_annotations_ALL.csv")

# %%
dfs = [df_illumina, df_hybrid, df_metaflye]
df_all = pd.concat(dfs)
df_all
# Out:
#         staxids                  sample  count
# 0             2   1903c111_10m-1_SPAdes    217
# 1             2   1903c111_10m-2_SPAdes    141
# 2             2   1903c117_50m-1_SPAdes    185
# 3             2   1903c117_50m-2_SPAdes     83
# 4             2   1903c119_11m-2_SPAdes    102
# ...         ...                     ...    ...
# 183576   989422  1903c127_7m-3_metaFlye      1
# 183577   989436  1903c127_7m-3_metaFlye      1
# 183578      991  1903c127_7m-3_metaFlye      1
# 183579      996  1903c127_7m-3_metaFlye      1
# 183580    99653  1903c127_7m-3_metaFlye      2
#
# [2008211 rows x 3 columns]

# %%
# pivot table so each sample is a column and counts are values
df_all_pivot = df_all.pivot(index='staxids', columns='sample', values='count')

# %%
df_all_pivot
# Out:
# sample   1903c111_10m-1_SPAdes  1903c111_10m-2_SPAdes  \
# staxids
# 2                        217.0                  141.0
# 6                          6.0                    3.0
# 7                         54.0                   52.0
# 9                         26.0                   24.0
# 10                        54.0                   33.0
# ...                        ...                    ...
# 2928627                   28.0                   17.0
# 2928628                   29.0                   17.0
# 2928629                   46.0                   34.0
# 2928680                    NaN                    NaN
# 2929456                    NaN                    3.0
#
# sample   1903c111_10m-3_metaFlye  1903c111_10m_hybridSPAdes  \
# staxids
# 2                           17.0                      142.0
# 6                            NaN                        3.0
# 7                            NaN                       52.0
# 9                            NaN                       24.0
# 10                           NaN                       34.0
# ...                          ...                        ...
# 2928627                      1.0                       17.0
# 2928628                      1.0                       17.0
# 2928629                      2.0                       34.0
# 2928680                      NaN                        NaN
# 2929456                      NaN                        3.0
#
# sample   1903c117_50m-1_SPAdes  1903c117_50m-2_SPAdes  \
# staxids
# 2                        185.0                   83.0
# 6                          3.0                    1.0
# 7                         40.0                    9.0
# 9                         16.0                   19.0
# 10                        32.0                   10.0
# ...                        ...                    ...
# 2928627                    1.0                    2.0
# 2928628                    2.0                    1.0
# 2928629                    7.0                    2.0
# 2928680                    1.0                    NaN
# 2929456                    2.0                    NaN
#
# sample   1903c117_50m-3_metaFlye  1903c117_50m_hybridSPAdes  \
# staxids
# 2                           46.0                      187.0
# 6                            1.0                        2.0
# 7                           20.0                       39.0
# 9                           13.0                       18.0
# 10                           6.0                       29.0
# ...                          ...                        ...
# 2928627                      4.0                        2.0
# 2928628                     10.0                        3.0
# 2928629                      2.0                        7.0
# 2928680                      NaN                        1.0
# 2929456                      3.0                        2.0
#
# sample   1903c118_23m-3_metaFlye  1903c118_23m_hybridSPAdes  ...  \
# staxids                                                      ...
# 2                            NaN                       21.0  ...
# 6                            NaN                        4.0  ...
# 7                            NaN                        5.0  ...
# 9                            NaN                       17.0  ...
# 10                           NaN                        5.0  ...
# ...                          ...                        ...  ...
# 2928627                      NaN                        2.0  ...
# 2928628                      NaN                        NaN  ...
# 2928629                      NaN                        1.0  ...
# 2928680                      NaN                        NaN  ...
# 2929456                      NaN                        NaN  ...
#
# sample   Las19c107_10m-2_SPAdes  Las19c107_10m-3_metaFlye  \
# staxids
# 2                         218.0                       NaN
# 6                           7.0                       NaN
# 7                          38.0                       NaN
# 9                          26.0                       NaN
# 10                         38.0                       NaN
# ...                         ...                       ...
# 2928627                     4.0                       NaN
# 2928628                     NaN                       NaN
# 2928629                     2.0                       NaN
# 2928680                     NaN                       NaN
# 2929456                     3.0                       NaN
#
# sample   Las19c107_10m_hybridSPAdes  Las19c135_5m-1_SPAdes  \
# staxids
# 2                             221.0                  175.0
# 6                               7.0                    6.0
# 7                              38.0                   75.0
# 9                              26.0                    9.0
# 10                             37.0                   23.0
# ...                             ...                    ...
# 2928627                         4.0                    3.0
# 2928628                         NaN                    3.0
# 2928629                         2.0                    5.0
# 2928680                         NaN                    NaN
# 2929456                         3.0                    1.0
#
# sample   Las19c135_5m-2_SPAdes  Las19c135_5m-3_metaFlye  \
# staxids
# 2                        165.0                    138.0
# 6                          3.0                      1.0
# 7                         55.0                      7.0
# 9                         43.0                     12.0
# 10                        24.0                      5.0
# ...                        ...                      ...
# 2928627                   10.0                     34.0
# 2928628                    4.0                     21.0
# 2928629                    5.0                     37.0
# 2928680                    NaN                      NaN
# 2929456                    1.0                      3.0
#
# sample   Las19c135_5m_hybridSPAdes  Las19c138_27m-1_SPAdes  \
# staxids
# 2                            164.0                   298.0
# 6                              3.0                    12.0
# 7                             54.0                   110.0
# 9                             44.0                    76.0
# 10                            23.0                    26.0
# ...                            ...                     ...
# 2928627                       10.0                    14.0
# 2928628                        4.0                     9.0
# 2928629                        5.0                    25.0
# 2928680                        NaN                     NaN
# 2929456                        1.0                    12.0
#
# sample   Las19c138_27m-3_metaFlye  Las19c138_27m_hybridSPAdes
# staxids
# 2                            21.0                       322.0
# 6                             NaN                        11.0
# 7                             5.0                       117.0
# 9                            13.0                        70.0
# 10                            NaN                        24.0
# ...                           ...                         ...
# 2928627                       2.0                        14.0
# 2928628                       NaN                        11.0
# 2928629                       5.0                        26.0
# 2928680                       NaN                         NaN
# 2929456                       NaN                        15.0
#
# [104702 rows x 51 columns]

# %%
df_all_pivot = df_all_pivot.fillna(0)
df_all_pivot
# Out:
# sample   1903c111_10m-1_SPAdes  1903c111_10m-2_SPAdes  \
# staxids
# 2                        217.0                  141.0
# 6                          6.0                    3.0
# 7                         54.0                   52.0
# 9                         26.0                   24.0
# 10                        54.0                   33.0
# ...                        ...                    ...
# 2928627                   28.0                   17.0
# 2928628                   29.0                   17.0
# 2928629                   46.0                   34.0
# 2928680                    0.0                    0.0
# 2929456                    0.0                    3.0
#
# sample   1903c111_10m-3_metaFlye  1903c111_10m_hybridSPAdes  \
# staxids
# 2                           17.0                      142.0
# 6                            0.0                        3.0
# 7                            0.0                       52.0
# 9                            0.0                       24.0
# 10                           0.0                       34.0
# ...                          ...                        ...
# 2928627                      1.0                       17.0
# 2928628                      1.0                       17.0
# 2928629                      2.0                       34.0
# 2928680                      0.0                        0.0
# 2929456                      0.0                        3.0
#
# sample   1903c117_50m-1_SPAdes  1903c117_50m-2_SPAdes  \
# staxids
# 2                        185.0                   83.0
# 6                          3.0                    1.0
# 7                         40.0                    9.0
# 9                         16.0                   19.0
# 10                        32.0                   10.0
# ...                        ...                    ...
# 2928627                    1.0                    2.0
# 2928628                    2.0                    1.0
# 2928629                    7.0                    2.0
# 2928680                    1.0                    0.0
# 2929456                    2.0                    0.0
#
# sample   1903c117_50m-3_metaFlye  1903c117_50m_hybridSPAdes  \
# staxids
# 2                           46.0                      187.0
# 6                            1.0                        2.0
# 7                           20.0                       39.0
# 9                           13.0                       18.0
# 10                           6.0                       29.0
# ...                          ...                        ...
# 2928627                      4.0                        2.0
# 2928628                     10.0                        3.0
# 2928629                      2.0                        7.0
# 2928680                      0.0                        1.0
# 2929456                      3.0                        2.0
#
# sample   1903c118_23m-3_metaFlye  1903c118_23m_hybridSPAdes  ...  \
# staxids                                                      ...
# 2                            0.0                       21.0  ...
# 6                            0.0                        4.0  ...
# 7                            0.0                        5.0  ...
# 9                            0.0                       17.0  ...
# 10                           0.0                        5.0  ...
# ...                          ...                        ...  ...
# 2928627                      0.0                        2.0  ...
# 2928628                      0.0                        0.0  ...
# 2928629                      0.0                        1.0  ...
# 2928680                      0.0                        0.0  ...
# 2929456                      0.0                        0.0  ...
#
# sample   Las19c107_10m-2_SPAdes  Las19c107_10m-3_metaFlye  \
# staxids
# 2                         218.0                       0.0
# 6                           7.0                       0.0
# 7                          38.0                       0.0
# 9                          26.0                       0.0
# 10                         38.0                       0.0
# ...                         ...                       ...
# 2928627                     4.0                       0.0
# 2928628                     0.0                       0.0
# 2928629                     2.0                       0.0
# 2928680                     0.0                       0.0
# 2929456                     3.0                       0.0
#
# sample   Las19c107_10m_hybridSPAdes  Las19c135_5m-1_SPAdes  \
# staxids
# 2                             221.0                  175.0
# 6                               7.0                    6.0
# 7                              38.0                   75.0
# 9                              26.0                    9.0
# 10                             37.0                   23.0
# ...                             ...                    ...
# 2928627                         4.0                    3.0
# 2928628                         0.0                    3.0
# 2928629                         2.0                    5.0
# 2928680                         0.0                    0.0
# 2929456                         3.0                    1.0
#
# sample   Las19c135_5m-2_SPAdes  Las19c135_5m-3_metaFlye  \
# staxids
# 2                        165.0                    138.0
# 6                          3.0                      1.0
# 7                         55.0                      7.0
# 9                         43.0                     12.0
# 10                        24.0                      5.0
# ...                        ...                      ...
# 2928627                   10.0                     34.0
# 2928628                    4.0                     21.0
# 2928629                    5.0                     37.0
# 2928680                    0.0                      0.0
# 2929456                    1.0                      3.0
#
# sample   Las19c135_5m_hybridSPAdes  Las19c138_27m-1_SPAdes  \
# staxids
# 2                            164.0                   298.0
# 6                              3.0                    12.0
# 7                             54.0                   110.0
# 9                             44.0                    76.0
# 10                            23.0                    26.0
# ...                            ...                     ...
# 2928627                       10.0                    14.0
# 2928628                        4.0                     9.0
# 2928629                        5.0                    25.0
# 2928680                        0.0                     0.0
# 2929456                        1.0                    12.0
#
# sample   Las19c138_27m-3_metaFlye  Las19c138_27m_hybridSPAdes
# staxids
# 2                            21.0                       322.0
# 6                             0.0                        11.0
# 7                             5.0                       117.0
# 9                            13.0                        70.0
# 10                            0.0                        24.0
# ...                           ...                         ...
# 2928627                       2.0                        14.0
# 2928628                       0.0                        11.0
# 2928629                       5.0                        26.0
# 2928680                       0.0                         0.0
# 2929456                       0.0                        15.0
#
# [104702 rows x 51 columns]

# %% [markdown]
# #### Convert floats to integers

# %%
df_all_pivot = df_all_pivot.astype(int)
df_all_pivot

# %%
df_all_pivot.to_csv("metaflye_hybrid_illumina_dfs.tsv", sep="\t")

# %%
df_all_pivot = pd.read_csv("metaflye_hybrid_illumina_dfs.txt", sep="\t", index_col=0)

# %%
df_all_pivot
# Out:
#          1903c111_10m-1_SPAdes  1903c111_10m-2_SPAdes  \
# 2                          217                    141
# 6                            6                      3
# 7                           54                     52
# 9                           26                     24
# 10                          54                     33
# ...                        ...                    ...
# 2928627                     28                     17
# 2928628                     29                     17
# 2928629                     46                     34
# 2928680                      0                      0
# 2929456                      0                      3
#
#          1903c111_10m-3_metaFlye  1903c111_10m_hybridSPAdes  \
# 2                             17                        142
# 6                              0                          3
# 7                              0                         52
# 9                              0                         24
# 10                             0                         34
# ...                          ...                        ...
# 2928627                        1                         17
# 2928628                        1                         17
# 2928629                        2                         34
# 2928680                        0                          0
# 2929456                        0                          3
#
#          1903c117_50m-1_SPAdes  1903c117_50m-2_SPAdes  \
# 2                          185                     83
# 6                            3                      1
# 7                           40                      9
# 9                           16                     19
# 10                          32                     10
# ...                        ...                    ...
# 2928627                      1                      2
# 2928628                      2                      1
# 2928629                      7                      2
# 2928680                      1                      0
# 2929456                      2                      0
#
#          1903c117_50m-3_metaFlye  1903c117_50m_hybridSPAdes  \
# 2                             46                        187
# 6                              1                          2
# 7                             20                         39
# 9                             13                         18
# 10                             6                         29
# ...                          ...                        ...
# 2928627                        4                          2
# 2928628                       10                          3
# 2928629                        2                          7
# 2928680                        0                          1
# 2929456                        3                          2
#
#          1903c118_23m-3_metaFlye  1903c118_23m_hybridSPAdes  ...  \
# 2                              0                         21  ...
# 6                              0                          4  ...
# 7                              0                          5  ...
# 9                              0                         17  ...
# 10                             0                          5  ...
# ...                          ...                        ...  ...
# 2928627                        0                          2  ...
# 2928628                        0                          0  ...
# 2928629                        0                          1  ...
# 2928680                        0                          0  ...
# 2929456                        0                          0  ...
#
#          Las19c107_10m-2_SPAdes  Las19c107_10m-3_metaFlye  \
# 2                           218                         0
# 6                             7                         0
# 7                            38                         0
# 9                            26                         0
# 10                           38                         0
# ...                         ...                       ...
# 2928627                       4                         0
# 2928628                       0                         0
# 2928629                       2                         0
# 2928680                       0                         0
# 2929456                       3                         0
#
#          Las19c107_10m_hybridSPAdes  Las19c135_5m-1_SPAdes  \
# 2                               221                    175
# 6                                 7                      6
# 7                                38                     75
# 9                                26                      9
# 10                               37                     23
# ...                             ...                    ...
# 2928627                           4                      3
# 2928628                           0                      3
# 2928629                           2                      5
# 2928680                           0                      0
# 2929456                           3                      1
#
#          Las19c135_5m-2_SPAdes  Las19c135_5m-3_metaFlye  \
# 2                          165                      138
# 6                            3                        1
# 7                           55                        7
# 9                           43                       12
# 10                          24                        5
# ...                        ...                      ...
# 2928627                     10                       34
# 2928628                      4                       21
# 2928629                      5                       37
# 2928680                      0                        0
# 2929456                      1                        3
#
#          Las19c135_5m_hybridSPAdes  Las19c138_27m-1_SPAdes  \
# 2                              164                     298
# 6                                3                      12
# 7                               54                     110
# 9                               44                      76
# 10                              23                      26
# ...                            ...                     ...
# 2928627                         10                      14
# 2928628                          4                       9
# 2928629                          5                      25
# 2928680                          0                       0
# 2929456                          1                      12
#
#          Las19c138_27m-3_metaFlye  Las19c138_27m_hybridSPAdes
# 2                              21                         322
# 6                               0                          11
# 7                               5                         117
# 9                              13                          70
# 10                              0                          24
# ...                           ...                         ...
# 2928627                         2                          14
# 2928628                         0                          11
# 2928629                         5                          26
# 2928680                         0                           0
# 2929456                         0                          15
#
# [104702 rows x 51 columns]

# %%
df_all_pivot += 1

# %%
df_all_pivot
# Out:
#          1903c111_10m-1_SPAdes  1903c111_10m-2_SPAdes  \
# 2                          218                    142
# 6                            7                      4
# 7                           55                     53
# 9                           27                     25
# 10                          55                     34
# ...                        ...                    ...
# 2928627                     29                     18
# 2928628                     30                     18
# 2928629                     47                     35
# 2928680                      1                      1
# 2929456                      1                      4
#
#          1903c111_10m-3_metaFlye  1903c111_10m_hybridSPAdes  \
# 2                             18                        143
# 6                              1                          4
# 7                              1                         53
# 9                              1                         25
# 10                             1                         35
# ...                          ...                        ...
# 2928627                        2                         18
# 2928628                        2                         18
# 2928629                        3                         35
# 2928680                        1                          1
# 2929456                        1                          4
#
#          1903c117_50m-1_SPAdes  1903c117_50m-2_SPAdes  \
# 2                          186                     84
# 6                            4                      2
# 7                           41                     10
# 9                           17                     20
# 10                          33                     11
# ...                        ...                    ...
# 2928627                      2                      3
# 2928628                      3                      2
# 2928629                      8                      3
# 2928680                      2                      1
# 2929456                      3                      1
#
#          1903c117_50m-3_metaFlye  1903c117_50m_hybridSPAdes  \
# 2                             47                        188
# 6                              2                          3
# 7                             21                         40
# 9                             14                         19
# 10                             7                         30
# ...                          ...                        ...
# 2928627                        5                          3
# 2928628                       11                          4
# 2928629                        3                          8
# 2928680                        1                          2
# 2929456                        4                          3
#
#          1903c118_23m-3_metaFlye  1903c118_23m_hybridSPAdes  ...  \
# 2                              1                         22  ...
# 6                              1                          5  ...
# 7                              1                          6  ...
# 9                              1                         18  ...
# 10                             1                          6  ...
# ...                          ...                        ...  ...
# 2928627                        1                          3  ...
# 2928628                        1                          1  ...
# 2928629                        1                          2  ...
# 2928680                        1                          1  ...
# 2929456                        1                          1  ...
#
#          Las19c107_10m-2_SPAdes  Las19c107_10m-3_metaFlye  \
# 2                           219                         1
# 6                             8                         1
# 7                            39                         1
# 9                            27                         1
# 10                           39                         1
# ...                         ...                       ...
# 2928627                       5                         1
# 2928628                       1                         1
# 2928629                       3                         1
# 2928680                       1                         1
# 2929456                       4                         1
#
#          Las19c107_10m_hybridSPAdes  Las19c135_5m-1_SPAdes  \
# 2                               222                    176
# 6                                 8                      7
# 7                                39                     76
# 9                                27                     10
# 10                               38                     24
# ...                             ...                    ...
# 2928627                           5                      4
# 2928628                           1                      4
# 2928629                           3                      6
# 2928680                           1                      1
# 2929456                           4                      2
#
#          Las19c135_5m-2_SPAdes  Las19c135_5m-3_metaFlye  \
# 2                          166                      139
# 6                            4                        2
# 7                           56                        8
# 9                           44                       13
# 10                          25                        6
# ...                        ...                      ...
# 2928627                     11                       35
# 2928628                      5                       22
# 2928629                      6                       38
# 2928680                      1                        1
# 2929456                      2                        4
#
#          Las19c135_5m_hybridSPAdes  Las19c138_27m-1_SPAdes  \
# 2                              165                     299
# 6                                4                      13
# 7                               55                     111
# 9                               45                      77
# 10                              24                      27
# ...                            ...                     ...
# 2928627                         11                      15
# 2928628                          5                      10
# 2928629                          6                      26
# 2928680                          1                       1
# 2929456                          2                      13
#
#          Las19c138_27m-3_metaFlye  Las19c138_27m_hybridSPAdes
# 2                              22                         323
# 6                               1                          12
# 7                               6                         118
# 9                              14                          71
# 10                              1                          25
# ...                           ...                         ...
# 2928627                         3                          15
# 2928628                         1                          12
# 2928629                         6                          27
# 2928680                         1                           1
# 2929456                         1                          16
#
# [104702 rows x 51 columns]

# %%
df_all_pivot.to_csv("metaflye_hybrid_illumina_dfs-transf.tsv", sep="\t")

# %%
df_all_pivot.columns
# Out:
# Index(['1903c111_10m-1_SPAdes', '1903c111_10m-2_SPAdes',
#        '1903c111_10m-3_metaFlye', '1903c111_10m_hybridSPAdes',
#        '1903c117_50m-1_SPAdes', '1903c117_50m-2_SPAdes',
#        '1903c117_50m-3_metaFlye', '1903c117_50m_hybridSPAdes',
#        '1903c118_23m-3_metaFlye', '1903c118_23m_hybridSPAdes',
#        '1903c119_11m-2_SPAdes', '1903c119_11m-3_metaFlye',
#        '1903c119_11m_hybridSPAdes', '1903c122_28m-1_SPAdes',
#        '1903c122_28m-2_SPAdes', '1903c122_28m-3_metaFlye',
#        '1903c122_28m_hybridSPAdes', '1903c123_10m-1_SPAdes',
#        '1903c123_10m-2_SPAdes', '1903c123_10m-3_metaFlye',
#        '1903c123_10m_hybridSPAdes', '1903c124_15m-1_SPAdes',
#        '1903c124_15m-2_SPAdes', '1903c124_15m-3_metaFlye',
#        '1903c124_15m_hybridSPAdes', '1903c126_45m-1_SPAdes',
#        '1903c126_45m-2_SPAdes', '1903c126_45m-3_metaFlye',
#        '1903c126_45m_hybridSPAdes', '1903c127_7m-1_SPAdes',
#        '1903c127_7m-2_SPAdes', '1903c127_7m-3_metaFlye',
#        '1903c127_7m_hybridSPAdes', '1903c129_26m-1_SPAdes',
#        '1903c129_26m-2_SPAdes', '1903c129_26m-3_metaFlye',
#        '1903c129_26m_hybridSPAdes', '1903c144_13m-2_SPAdes',
#        '1903c144_13m-3_metaFlye', '1903c144_13m_hybridSPAdes',
#        'Las19c107_10m-1_SPAdes', 'Las19c107_10m-2_SPAdes',
#        'Las19c107_10m-3_metaFlye', 'Las19c107_10m_hybridSPAdes',
#        'Las19c135_5m-1_SPAdes', 'Las19c135_5m-2_SPAdes',
#        'Las19c135_5m-3_metaFlye', 'Las19c135_5m_hybridSPAdes',
#        'Las19c138_27m-1_SPAdes', 'Las19c138_27m-3_metaFlye',
#        'Las19c138_27m_hybridSPAdes'],
#       dtype='object')
